# %%
# !git clone https://gitee.com/xiaokang-zhang/LuoJiaChangeDetection.git

# %%
cd LuoJiaChangeDetection
# Out:
# /dls/app/LuoJiaChangeDetection

# %%
# !pip install -r requirements.txt

# %% [markdown]
# 训练:

# %%
# !python main.py --config configs/snunet/snunet_levir_train.yml
# Out:
# 2023-12-28 15:10:29 INFO  ============== Starting Training ==============
# [WARNING] ME(48482:140403058792256,MainProcess):2023-12-28-15:10:29.514.82 [luojianet/train/model.py:1100] For EvalCallback callback, {'epoch_end'} methods may not be supported in later version, Use methods prefixed with 'on_train' or 'on_eval' instead when using customized callbacks.
# epoch: 1 step: 40, loss is 0.06048774719238281
# Train epoch time: 233113.190 ms, per step time: 5827.830 ms
# epoch: 2 step: 40, loss is 0.06335805356502533
# Train epoch time: 166464.491 ms, per step time: 4161.612 ms
# epoch: 3 step: 40, loss is 0.0697685107588768
# Train epoch time: 164697.100 ms, per step time: 4117.427 ms
# epoch: 4 step: 40, loss is 0.06889539957046509
# Train epoch time: 165634.257 ms, per step time: 4140.856 ms
# epoch: 5 step: 40, loss is 0.06276129931211472
# Train epoch time: 163585.504 ms, per step time: 4089.638 ms
# ---Evaluation completed! The test mIoU is 0.5168962278748511---.

# %% [markdown]
# 测试:

# %%
# !python main.py --config configs/snunet/snunet_levir_test.yml
# Out:
# 2023-12-28 15:31:55 INFO  ============== Starting Testing ==============
# 2023-12-28 15:32:34 INFO  Test mIoU: 0.7426192662865752
# 2023-12-28 15:32:34 INFO  ============== Testing Finished==============
